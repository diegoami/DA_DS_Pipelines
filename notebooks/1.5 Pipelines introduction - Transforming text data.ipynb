# %%
from utils import css_from_file
css_from_file('style/style.css')
# Out:
# <style>/*@font-face {
# 	font-family: "Computer Modern";
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
# }*/
#
# .navbar-brand, .current_kernel_logo {display:none}
# .container {
#     width:80%;
# }
#
# h1 {
# 	font-family: Helvetica, serif;
# }
# h4{
# 	margin-top:12px;
# 	margin-bottom: 3px;
#    }
# div.text_cell_render{
# 	font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
# 	line-height: 145%;
# 	font-size: 100%;
# 	width:100%;
# 	margin-left:auto;
# 	margin-right:auto;
# }
# .CodeMirror{
# 		font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
# }
# .text_cell_render h5 {
# 	font-weight: 300;
# 	font-size: 22pt;
# 	/*color: #4057A1;*/
# 	font-style: italic;
# 	margin-bottom: .5em;
# 	margin-top: 0.5em;
# 	display: block;
# }
#
# .warning{
# 	color: rgb( 240, 20, 20 )
# 	}
#
# div.spoiler {
# 	display: none;
# }
#
# .rendered_html code {
# 	border: 0;
# 	/*background-color: #eee;*/
# 	font-size: 100%;
# 	padding: 1px 2px;
# }
# </style>

# %%
import re
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import (
    CountVectorizer, TfidfVectorizer, HashingVectorizer
)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Read csv file into a dataframe

# %%
df = pd.read_csv("data/ebaytitles.csv")
df = df.sample(frac=0.1) # delete this line if you are brave and have many GBs of RAM
df.head()
# Out:
#                                                     title  \
# 876808  TITANIUM PURPLE 6PC SCREEN BOLT KIT FITS YAMAH...
# 850868  9ct Yellow Gold 4mm Mediumweight D-Shape Weddi...
# 926759  2.4G Wireless / Cordless Optical Mouse with US...
# 840213  London Westminster River Thames View Large Wal...
# 506121  EVOTECH ALLOY REAR WHEEL AXLE NUT BLUE FITS HO...
#
#                          category_name
# 876808     Vehicle Parts & Accessories
# 850868             Jewellery & Watches
# 926759  Computers/Tablets & Networking
# 840213                             Art
# 506121     Vehicle Parts & Accessories

# %% [markdown]
# Print out unique values of a column

# %%
df.category_name.unique()
# Out:
# array(['Vehicle Parts & Accessories', 'Jewellery & Watches',
#        'Computers/Tablets & Networking', 'Art',
#        'Clothes, Shoes & Accessories', 'Mobile Phones & Communication',
#        'Toys & Games', 'Musical Instruments & Gear', 'Garden & Patio',
#        'Collectibles', 'Sound & Vision', 'Crafts', 'Sporting Goods',
#        'Baby', 'Home, Furniture & DIY', 'Books, Comics & Magazines',
#        'Health & Beauty', 'Sports Memorabilia',
#        'Business, Office & Industrial', 'Music', 'Stamps', 'Pet Supplies',
#        'Video Games & Consoles', 'DVDs, Films & TV', 'Coins & Paper Money',
#        'Cameras & Photography', 'Consumer Electronics', 'Antiques',
#        'Pottery, Porcelain & Glass', 'Holidays & Travel',
#        'Wholesale & Job Lots', 'Dolls & Bears', 'Everything Else',
#        'Cell Phones & Accessories', 'Travel', 'Entertainment Memorabilia'], dtype=object)

# %% [markdown]
# Split the data into train and test observations - there is a column

# %%
X = df.title.values
y = df.category_name.values

X_tr, X_te, y_tr, y_te = train_test_split(X, 
                                          y,
                                          test_size=0.1,
                                          random_state=0)

# %%
df
# Out:
#                                                     title  \
# 876808  TITANIUM PURPLE 6PC SCREEN BOLT KIT FITS YAMAH...
# 850868  9ct Yellow Gold 4mm Mediumweight D-Shape Weddi...
# 926759  2.4G Wireless / Cordless Optical Mouse with US...
# 840213  London Westminster River Thames View Large Wal...
# 506121  EVOTECH ALLOY REAR WHEEL AXLE NUT BLUE FITS HO...
# 418283  Mens Denim Shirt By Soul Star Long Sleeved 'So...
# 977743                 Nokia 6220/6230 Black Leather Case
# 68541   Regatta Mens Bodywarmer Waistcoat Polycotton M...
# 267261  Packhorse Bridge Jigsaw Puzzle - 2000 Pieces -...
# 364163  BRAND NEW WINDOW SWITCH LIFTER WINDER SEAT LEO...
# 253332  New MakeMusic Finale Music 2014 Professional S...
# 953240  CYBER GEISHA PIXIE HOOD FLEECE JACKET festival...
# 823787  15-17mm Fork Stem Motorcycle Bike Yoke Mount f...
# 981586  26" NET BAG FOR FILTER MEDIA. KOI POND FILTER ...
# 318595           Gold Military US Navy Seals Insignia Pin
# 340183  Land Rover Discovery Front Radius Arm Axle Bus...
# 883508  NEW 50 MIXED 22mm GLASS MARBLES TRADITIONAL GA...
# 225401  VTECH POWER XTRA LAPTOP POWER SUPPLY CHARGER A...
# 420969  Rainbow Dust Edible Party Cake Plain and Simpl...
# 303635  AMBROSIO ATRITIUM-3 CLIP-ON BARS, 31.8MM BLACK...
# 159299  GENUINE CLEAR Westfield/Caterham Rear Light/la...
# 342686  RED 501 T10 W5W 6 LED SIDELIGHTS 1 X PAIR GREA...
# 623524  MINI DIGITAL TYRE PRESSURE GAUGE KEYRING IN ME...
# 905663  FCB Barcelona Nike Boys Home Football T Shirt ...
# 324920  Brand New Phil & teds sport pushchair inner tu...
# 881705  Custom Printed T-Shirts Personalised Stag Team...
# 286838  XENON H7 HID KIT 55W FOR Alfa Romeo 166 MODELS...
# 446805  KNOX DRY INSIDE PERFORMANCE BASE LAYER TOP JER...
# 710712  London Midland Scottish Railway LMS150 Patrick...
# 850112  TOYOTA URBAN CRUISER   HEAVY DUTY GREY WATERPR...
# ...                                                   ...
# 98907   1951 63rd Birthday Anniversary Farthing coin i...
# 984793  Careful Driving Enamel Mug ~ Postal Museum & A...
# 845699  Astor Anti Shine Mattitude Supermatte Powder -...
# 284664  TOSHIBA SATELLITE U400 MULTIMEDIA LED BOARD WI...
# 113413  PEACOCK STIRRUPS HORSE RIDING SAFETY IRON FILL...
# 897827  Costume Jewellery Stretch Elastic Crystal Diam...
# 12906   24 x Children's A5 Magic Painting Colouring In...
# 556748  BP01-EN084 Forbidden Lance 1st Edition Mint Yu...
# 284694  Cod Pollack & Mackerel Sea fishing Feather Rig...
# 653466  Kiam Ultra Eco 190 Space Heater 190,000 Btu 56...
# 378551  NUMBER PLATE BULBS LIGHT LED BRIGHT WHITE XENO...
# 261647  RAMAIR Performance Panel Air Filter Race Foam ...
# 699085  YooHoo & Friends 8" Plush Toy - Ring Ring The ...
# 259019  Home Work Out Resistance Bands Kit Set Abs Fit...
# 339970  INTEGRAL 8GB COURIER USB FLASH MEMORY STICK PE...
# 908663  HAYNES OWNERS WORKSHOP MANUAL PEUGEOT 206 PETR...
# 288701  LARGE QUALITY FLAG OF CHE GUEVARA CUBA REBEL P...
# 637504  MICROBE LIFT HERBTANA  473ml 100% natural trea...
# 690051  Christys of London Brown Chepstow Snap Brim Wo...
# 153672       Organic Surge Sweet Blossom Shower Gel 250ml
# 305404  VW Beetle / Camper T2 Yellow HT Ignition Leads...
# 561672  Blueprint Oil Filter Honda Civic EG EJ EH JDM ...
# 585879  400g DARK GREEN COLOUR DYLON MACHINE WASH FABR...
# 505367  PRO SPEC TITANIUM SCREEN BOLT KIT FITS HONDA C...
# 735801  Spoon Busk, Corset Fastener, 11", 28cm, Five H...
# 544896  20 x Miele GN S626 S646 S828 S846 S634 S648 S8...
# 81664   PURPLE PULL TAB SLIDE IN POUCH+SLIMLINE METAL ...
# 377104  Traditional Extra wide stainless steel shaving...
# 791714               Piezo Buzzer  5pcs = £1.90 item 1306
# 113428                     District Logo Bar Ends - Steel
#
#                          category_name
# 876808     Vehicle Parts & Accessories
# 850868             Jewellery & Watches
# 926759  Computers/Tablets & Networking
# 840213                             Art
# 506121     Vehicle Parts & Accessories
# 418283    Clothes, Shoes & Accessories
# 977743   Mobile Phones & Communication
# 68541     Clothes, Shoes & Accessories
# 267261                    Toys & Games
# 364163     Vehicle Parts & Accessories
# 253332      Musical Instruments & Gear
# 953240    Clothes, Shoes & Accessories
# 823787   Mobile Phones & Communication
# 981586                  Garden & Patio
# 318595                    Collectibles
# 340183     Vehicle Parts & Accessories
# 883508                    Toys & Games
# 225401                  Sound & Vision
# 420969                          Crafts
# 303635                  Sporting Goods
# 159299     Vehicle Parts & Accessories
# 342686     Vehicle Parts & Accessories
# 623524     Vehicle Parts & Accessories
# 905663    Clothes, Shoes & Accessories
# 324920                            Baby
# 881705           Home, Furniture & DIY
# 286838     Vehicle Parts & Accessories
# 446805     Vehicle Parts & Accessories
# 710712       Books, Comics & Magazines
# 850112     Vehicle Parts & Accessories
# ...                                ...
# 98907              Jewellery & Watches
# 984793           Home, Furniture & DIY
# 845699                 Health & Beauty
# 284664  Computers/Tablets & Networking
# 113413                  Sporting Goods
# 897827             Jewellery & Watches
# 12906        Books, Comics & Magazines
# 556748                    Collectibles
# 284694                  Sporting Goods
# 653466           Home, Furniture & DIY
# 378551     Vehicle Parts & Accessories
# 261647     Vehicle Parts & Accessories
# 699085                    Toys & Games
# 259019                  Sporting Goods
# 339970  Computers/Tablets & Networking
# 908663     Vehicle Parts & Accessories
# 288701                    Collectibles
# 637504                    Pet Supplies
# 690051    Clothes, Shoes & Accessories
# 153672                 Health & Beauty
# 305404     Vehicle Parts & Accessories
# 561672     Vehicle Parts & Accessories
# 585879                          Crafts
# 505367     Vehicle Parts & Accessories
# 735801                          Crafts
# 544896           Home, Furniture & DIY
# 81664    Mobile Phones & Communication
# 377104                    Collectibles
# 791714   Business, Office & Industrial
# 113428                  Sporting Goods
#
# [100000 rows x 2 columns]

# %% [markdown]
# Exercise
# ------------------
#
# 1. Count how many titles are in each category (```pandas.DataFrame.groupby```). Print out most common at the top

# %%
##########################
# put your solution here #
##########################
df.groupby('category_name').count().sort_values('title', ascending=False)
# Out:
#                                 title
# category_name
# Vehicle Parts & Accessories     23088
# Clothes, Shoes & Accessories    16740
# Home, Furniture & DIY           12862
# Computers/Tablets & Networking   6739
# Jewellery & Watches              6327
# Sporting Goods                   4745
# Mobile Phones & Communication    3990
# Health & Beauty                  3327
# Crafts                           3325
# Toys & Games                     2882
# Business, Office & Industrial    2872
# Collectibles                     2434
# Sound & Vision                   1894
# Music                            1361
# Garden & Patio                   1033
# Cameras & Photography             852
# Baby                              734
# DVDs, Films & TV                  610
# Pet Supplies                      608
# Art                               597
# Video Games & Consoles            478
# Musical Instruments & Gear        453
# Books, Comics & Magazines         440
# Sports Memorabilia                298
# Dolls & Bears                     257
# Antiques                          216
# Coins & Paper Money               195
# Everything Else                   149
# Consumer Electronics              145
# Wholesale & Job Lots              104
# Pottery, Porcelain & Glass         89
# Stamps                             84
# Cell Phones & Accessories          57
# Entertainment Memorabilia           8
# Holidays & Travel                   6
# Travel                              1

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# frequencies = df.groupby("category_name")["title"].count()
# frequencies.sort_values(inplace=True,ascending=False)
# print(frequencies)
#
# # or faster
#
# df.category_name.value_counts()
#
# </div>

# %% [markdown]
# Bag of words
# --------------------
#
# Different types of vectorizers:
#
# <ul>
# <li>```sklearn.feature_extraction.text.CountVectorizer``` - Counts the number of times a word appears in the text</li>
# <li>```sklearn.feature_extraction.text.TfidfVectorizer``` - Weighs the words according to the importance of the word in the context of whole collection. Is the word ```the``` important if it appears in all documents?</li>
# <li>```sklearn.feature_extraction.text.HashingVectorizer``` - Useful when you don't know the vocabulary upfront. Feature number is calculated as ```hash(token) % vocabulary_size```.</li>
# </ul>

# %% [markdown]
# Exercise
# -------------------
# 1. Use ```CountVectorizer``` / ```TfidfVectorizer``` to fit the collection of documents
# 2. How many unique tokens are there in text? Print some examples (ie first few hundred).
# 3. What methods you can use to reduce this number?
#    - Check out and experiment with the arguments: ```ngram_range```, ```min_df```. How the vocabulary size changes with each change?
#    - What would you replace / delete from the text?
# 4. Write a custom function `clean_text` that accepts a text as input and transforms it (remove/hash numbers, delete short/long words etc.)
# 5. (Extra points) When would you use ```HashingVectorizer```?

# %%
##########################
# put your solution here #
##########################
cv = CountVectorizer()
cv.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in a naive approach ???")
#print(sum([x[1] for x in cv.vocabulary_.items()]))
print(len(cv.vocabulary_))
# Out:
# How many unique tokens in a naive approach ???
# 71782

# %%
cv_min_5_max_07 = CountVectorizer(min_df=5, max_df=0.7)
cv_min_5_max_07.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_5_max_07 ???")
print(len( cv_min_5_max_07.vocabulary_))
# Out:
# How many unique tokens in cv_min_5_max_07 ???
# 13882

# %%
cv_min_4_max_07 = CountVectorizer(min_df=4, max_df=0.7)
cv_min_4_max_07.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_4_max_07 ???")
print(len( cv_min_4_max_07.vocabulary_))
# Out:
# How many unique tokens in cv_min_4_max_07 ???
# 16292

# %%
cv_min_3_max_07 = CountVectorizer(min_df=3, max_df=0.7)
cv_min_3_max_07.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_3_max_07 ???")
print(len( cv_min_3_max_07.vocabulary_))
# Out:
# How many unique tokens in cv_min_3_max_07 ???
# 20211

# %%
cv_min_2_max_07 = CountVectorizer(min_df=2, max_df=0.7)
cv_min_2_max_07.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_2_max_07 ???")
print(len( cv_min_2_max_07.vocabulary_))
# Out:
# How many unique tokens in cv_min_2_max_07 ???
# 29259

# %%
cv_min_5_max_07_ngr = CountVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2))
cv_min_5_max_07_ngr.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_5_max_07_ngr ???")
print(len( cv_min_5_max_07_ngr.vocabulary_))
# Out:
# How many unique tokens in cv_min_5_max_07_ngr ???
# 36471

# %%
import re
def clean_text(str):
    str = str.lower()
    str = re.sub(r'\b[0-9]+[A-Za-z]+\b', '#', str)
    str = re.sub(r'\b[0-9]+\b', '#', str)
    str = re.sub(r'\b[A-Za-z]+[0-9]+\b', '#', str)
    return str
    
    
print(clean_text('test 1'))    
print(clean_text('200 test '))    
print(clean_text('200gb test'))
# Out:
# test #
# # test
# # test

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
cv_min_5_max_07_ngr_ctxt = CountVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2), preprocessor=clean_text, stop_words=stop_words)
cv_min_5_max_07_ngr_ctxt.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_5_max_07_ngr ???")
print(len( cv_min_5_max_07_ngr_ctxt.vocabulary_))
[x for x in cv_min_5_max_07_ngr_ctxt.vocabulary_.items() if len(x[0].split()) > 1]
# Out:
# How many unique tokens in cv_min_5_max_07_ngr ???
# 30109
# [('brake pipe', 3178),
#  ('blue carbon', 2551),
#  ('carbon fiber', 4192),
#  ('fiber vinyl', 9185),
#  ('vinyl film', 28416),
#  ('film wrap', 9275),
#  ('wrap sheet', 29681),
#  ('sheet sticker', 23520),
#  ('sticker tint', 25450),
#  ('new cd', 17727),
#  ('black diamond', 2233),
#  ('edible cup', 8251),
#  ('cup cake', 6455),
#  ('cake toppers', 3861),
#  ('toppers rice', 27097),
#  ('rice paper', 21989),
#  ('adsl modem', 231),
#  ('lente designs', 14964),
#  ('designs apple', 7074),
#  ('apple ipad', 741),
#  ('cover case', 6071),
#  ('designer fabric', 7054),
#  ('new authentic', 17697),
#  ('authentic tag', 1107),
#  ('tag heuer', 26286),
#  ('heuer carrera', 12213),
#  ('leather strap', 14787),
#  ('jigsaw puzzle', 13537),
#  ('hi fi', 12232),
#  ('blue led', 2590),
#  ('mens lambretta', 16330),
#  ('mod retro', 16907),
#  ('union jack', 27891),
#  ('jack flag', 13356),
#  ('hand made', 11761),
#  ('snapback mens', 24598),
#  ('mens cap', 16273),
#  ('cap blue', 4021),
#  ('blue headwear', 2579),
#  ('white one', 29160),
#  ('one size', 18486),
#  ('carrier oil', 4282),
#  ('oil pure', 18413),
#  ('red large', 21591),
#  ('large plastic', 14563),
#  ('tailored exclusive', 26313),
#  ('exclusive rubber', 8735),
#  ('rubber mats', 22438),
#  ('mats heavy', 16053),
#  ('heavy duty', 12113),
#  ('new ngk', 17838),
#  ('ngk ignition', 17993),
#  ('ignition coil', 12902),
#  ('coil pack', 5444),
#  ('pack audi', 18782),
#  ('audi fsi', 1050),
#  ('avant estate', 1149),
#  ('plant food', 19983),
#  ('large wall', 14576),
#  ('wall sticker', 28686),
#  ('decal wallart', 6862),
#  ('cush drive', 6516),
#  ('drive rubbers', 7840),
#  ('sprocket rubbers', 25116),
#  ('suitable yamaha', 25847),
#  ('yamaha ybr', 29893),
#  ('land rover', 14494),
#  ('rover defender', 22366),
#  ('wheel bearing', 29045),
#  ('bearing hub', 1765),
#  ('hub nut', 12761),
#  ('air pump', 361),
#  ('pump new', 20904),
#  ('head screw', 11994),
#  ('school bag', 22823),
#  ('olive drab', 18445),
#  ('water filter', 28815),
#  ('flower rose', 9826),
#  ('red trim', 21625),
#  ('trim sewing', 27488),
#  ('sewing costume', 23380),
#  ('costume crafts', 5943),
#  ('mens jeans', 16322),
#  ('dell inspiron', 6957),
#  ('inspiron mini', 13124),
#  ('mini screen', 16714),
#  ('screen bezel', 22900),
#  ('double plug', 7641),
#  ('plug socket', 20150),
#  ('socket gang', 24655),
#  ('georgian brass', 10765),
#  ('rolling paper', 22236),
#  ('box booklets', 3027),
#  ('wi fi', 29230),
#  ('aerial antenna', 269),
#  ('latex mask', 14601),
#  ('fancy dress', 8969),
#  ('water filters', 28816),
#  ('dolls house', 7534),
#  ('house miniature', 12683),
#  ('miniature accessory', 16728),
#  ('pair black', 18951),
#  ('neoprene sleeve', 17646),
#  ('quick release', 21162),
#  ('ngk spark', 18000),
#  ('spark plug', 24859),
#  ('mitsubishi lancer', 16811),
#  ('estate mk', 8630),
#  ('mk iii', 16849),
#  ('glow plugs', 11049),
#  ('plugs renault', 20176),
#  ('renault clio', 21752),
#  ('new cute', 17738),
#  ('apple iphone', 742),
#  ('soft silicone', 24709),
#  ('back case', 1253),
#  ('case cover', 4326),
#  ('genuine german', 10688),
#  ('planer blade', 19975),
#  ('blade knives', 2459),
#  ('inc vat', 12966),
#  ('armour coldgear', 843),
#  ('top black', 27016),
#  ('black steel', 2385),
#  ('blue grey', 2576),
#  ('ladies pink', 14371),
#  ('fitted shirt', 9541),
#  ('shirt logo', 23615),
#  ('sizes bnwt', 24188),
#  ('desktop pc', 7091),
#  ('ford focus', 9991),
#  ('womens ladies', 29515),
#  ('heart print', 12062),
#  ('print long', 20648),
#  ('long sleeves', 15427),
#  ('knitted long', 14109),
#  ('jumper top', 13679),
#  ('fierce fast', 9202),
#  ('fast quadcore', 9021),
#  ('quadcore desktop', 21058),
#  ('desktop gaming', 7090),
#  ('gaming pc', 10468),
#  ('pc amd', 19305),
#  ('amd wrnty', 545),
#  ('brand new', 3190),
#  ('single double', 24091),
#  ('double king', 7637),
#  ('king size', 13935),
#  ('mens clarks', 16280),
#  ('brown leather', 3392),
#  ('leather casual', 14731),
#  ('hiking boots', 12330),
#  ('volvo heavy', 28535),
#  ('duty grey', 8036),
#  ('grey waterproof', 11451),
#  ('waterproof seat', 28857),
#  ('seat covers', 23063),
#  ('vauxhall omega', 28213),
#  ('stainless steel', 25207),
#  ('led light', 14851),
#  ('pin mains', 19786),
#  ('mains charger', 15793),
#  ('charger tablet', 4719),
#  ('tablet pc', 26259),
#  ('quick fix', 21160),
#  ('snap fit', 24590),
#  ('tap connector', 26373),
#  ('seiko sports', 23123),
#  ('automatic watch', 1129),
#  ('warranty box', 28750),
#  ('box rrp', 3037),
#  ('fishing tackle', 9429),
#  ('xternal portable', 29843),
#  ('portable charger', 20364),
#  ('charger battery', 4688),
#  ('battery power', 1643),
#  ('power bank', 20458),
#  ('nokia lumia', 18101),
#  ('fiesta fusion', 9208),
#  ('dress hen', 7738),
#  ('hen stag', 12182),
#  ('stag party', 25197),
#  ('party new', 19175),
#  ('d2s xenon', 6638),
#  ('xenon hid', 29771),
#  ('hid bulbs', 12252),
#  ('bulbs oem', 3571),
#  ('rover mg', 22372),
#  ('mg zt', 16536),
#  ('mens leather', 16332),
#  ('leather shoes', 14778),
#  ('shoes formal', 23703),
#  ('office work', 18356),
#  ('black brown', 2203),
#  ('brown size', 3405),
#  ('men sloggi', 16236),
#  ('white short', 29188),
#  ('briefs pack', 3283),
#  ('pack sizes', 18830),
#  ('sizes available', 24186),
#  ('white high', 29138),
#  ('high sensitive', 12298),
#  ('sensitive mini', 23163),
#  ('mini retractable', 16712),
#  ('retractable stylus', 21879),
#  ('stylus pen', 25774),
#  ('pen huawei', 19422),
#  ('huawei honor', 12753),
#  ('dc power', 6818),
#  ('power jack', 20468),
#  ('jack socket', 13369),
#  ('socket port', 24662),
#  ('port dell', 20353),
#  ('dell studio', 6963),
#  ('peugeot inj', 19611),
#  ('speed gearbox', 24940),
#  ('gearbox genuine', 10592),
#  ('bearing oil', 1767),
#  ('oil seal', 18414),
#  ('seal rebuild', 23018),
#  ('rebuild kit', 21525),
#  ('oil pressure', 18411),
#  ('pressure switch', 20581),
#  ('mens jack', 16320),
#  ('jack jones', 13360),
#  ('regular fit', 21688),
#  ('fit shirt', 9470),
#  ('black sheer', 2365),
#  ('plain black', 19957),
#  ('black top', 2404),
#  ('tights sexy', 26811),
#  ('sexy designer', 23396),
#  ('designer lingerie', 7059),
#  ('vw tiguan', 28595),
#  ('pencil ignition', 19441),
#  ('ignition coils', 12903),
#  ('coils packs', 5451),
#  ('packs genuine', 18855),
#  ('genuine bbt', 10657),
#  ('bbt oem', 1680),
#  ('oem quality', 18337),
#  ('ladies waterproof', 14418),
#  ('waterproof windproof', 28863),
#  ('camping hiking', 3950),
#  ('horse riding', 12617),
#  ('riding jacket', 22012),
#  ('sony vaio', 24789),
#  ('adapter pcg', 166),
#  ('pcg pcg', 19331),
#  ('left hand', 14891),
#  ('new ecoaqua', 17750),
#  ('ecoaqua eff', 8228),
#  ('eff refrigerator', 8282),
#  ('refrigerator water', 21674),
#  ('filter maytag', 9313),
#  ('maytag admiral', 16104),
#  ('professional quality', 20733),
#  ('party loot', 19172),
#  ('loot bag', 15460),
#  ('bag filler', 1330),
#  ('fast gaming', 9016),
#  ('amd quad', 542),
#  ('quad core', 21051),
#  ('core desktop', 5889),
#  ('desktop computer', 7089),
#  ('computer gfx', 5679),
#  ('baby blue', 1221),
#  ('blue high', 2582),
#  ('pen lg', 19424),
#  ('lg tri', 15028),
#  ('tri chip', 27447),
#  ('audi quattro', 1055),
#  ('turbo petrol', 27655),
#  ('petrol rear', 19588),
#  ('rear brake', 21471),
#  ('brake caliper', 3165),
#  ('caliper right', 3880),
#  ('right hand', 22024),
#  ('blue butterfly', 2549),
#  ('set real', 23329),
#  ('inspiron laptop', 13123),
#  ('long range', 15421),
#  ('walkie talkie', 28645),
#  ('two way', 27738),
#  ('way radio', 28892),
#  ('hi black', 12231),
#  ('black canvas', 2207),
#  ('canvas mens', 4011),
#  ('mens boots', 16267),
#  ('fridge magnet', 10157),
#  ('magnet og', 15758),
#  ('evening ballgown', 8684),
#  ('maxi dress', 16086),
#  ('evil eye', 8704),
#  ('janome new', 13425),
#  ('new singer', 17902),
#  ('sewing machines', 23384),
#  ('batteries charger', 1626),
#  ('charger panasonic', 4712),
#  ('vee belts', 28243),
#  ('wix oil', 29435),
#  ('oil filter', 18406),
#  ('filter eqv', 9295),
#  ('eqv fram', 8562),
#  ('motorbike motorcycle', 17130),
#  ('motorcycle speedo', 17186),
#  ('speedo cable', 24951),
#  ('new mens', 17829),
#  ('mens gents', 16302),
#  ('low profile', 15530),
#  ('soap mould', 24636),
#  ('mould cavity', 17207),
#  ('dyson dc25i', 8102),
#  ('vacuum cleaner', 28077),
#  ('cleaner washable', 5192),
#  ('pre motor', 20527),
#  ('motor filter', 17107),
#  ('wall decals', 28667),
#  ('children room', 4844),
#  ('room nursery', 22272),
#  ('new balance', 17699),
#  ('running sneaker', 22505),
#  ('purple yellow', 20970),
#  ('yellow white', 29933),
#  ('white size', 29193),
#  ('mens ladies', 16329),
#  ('ladies wedding', 14419),
#  ('false eyelashes', 8952),
#  ('lamp shades', 14469),
#  ('match children', 16028),
#  ('genuine ariston', 10652),
#  ('ariston fridge', 818),
#  ('shelf front', 23528),
#  ('front trim', 10241),
#  ('new sony', 17910),
#  ('laptop screen', 14539),
#  ('screen led', 22919),
#  ('led backlit', 14812),
#  ('backlit hd', 1287),
#  ('washing machine', 28780),
#  ('machine door', 15695),
#  ('door seal', 7596),
#  ('seal gasket', 23012),
#  ('super soft', 25922),
#  ('sugar skull', 25826),
#  ('cardigan banned', 4226),
#  ('knitted top', 14112),
#  ('renault laguna', 21757),
#  ('front abs', 10176),
#  ('abs sensor', 64),
#  ('crop top', 6335),
#  ('top vest', 27074),
#  ('xl xxl', 29803),
#  ('xxl xxxl', 29859),
#  ('replacement stylus', 21816),
#  ('stylus turntable', 25779),
#  ('turntable needle', 27675),
#  ('hair beauty', 11637),
#  ('tie rod', 26782),
#  ('rod end', 22199),
#  ('remover removal', 21743),
#  ('wrench tool', 29699),
#  ('black white', 2418),
#  ('hip hop', 12354),
#  ('tee shirt', 26522),
#  ('hid conversion', 12253),
#  ('conversion kit', 5788),
#  ('free gift', 10111),
#  ('led drl', 14833),
#  ('cast aluminium', 4383),
#  ('ferodo front', 9135),
#  ('front brake', 10184),
#  ('brake pads', 3176),
#  ('pads vauxhall', 18915),
#  ('vauxhall cavalier', 28204),
#  ('original oem', 18632),
#  ('crank shaft', 6224),
#  ('shaft pulley', 23436),
#  ('pulley torsion', 20873),
#  ('torsion vibration', 27118),
#  ('vibration dampner', 28347),
#  ('ktm sx', 14185),
#  ('rosary beads', 22282),
#  ('golf men', 11210),
#  ('white blue', 29091),
#  ('ski pants', 24240),
#  ('ice peak', 12857),
#  ('digital camera', 7291),
#  ('new flower', 17765),
#  ('flower girl', 9817),
#  ('girl party', 10862),
#  ('party bridesmaid', 19147),
#  ('dress scarf', 7759),
#  ('countersunk screws', 6035),
#  ('slotted head', 24479),
#  ('disney winnie', 7422),
#  ('winnie pooh', 29343),
#  ('days rtb', 6797),
#  ('rtb warranty', 22418),
#  ('two pack', 27734),
#  ('full cup', 10312),
#  ('marks spencer', 15938),
#  ('womens printed', 29533),
#  ('ladies short', 14391),
#  ('short sleeve', 23755),
#  ('top plus', 27050),
#  ('plus size', 20191),
#  ('radio controlled', 21263),
#  ('hid kit', 12257),
#  ('kit mercedes', 14008),
#  ('mercedes benz', 16427),
#  ('benz vito', 1932),
#  ('models bright', 16928),
#  ('shaft bearing', 23431),
#  ('genuine hotpoint', 10693),
#  ('dishwasher heater', 7398),
#  ('heater element', 12095),
#  ('endon lighting', 8470),
#  ('lighting metal', 15142),
#  ('single wall', 24102),
#  ('wall light', 28672),
#  ('light polished', 15110),
#  ('polished chrome', 20265),
#  ('shift dress', 23571),
#  ('dress size', 7766),
#  ('fuel petrol', 10293),
#  ('petrol tank', 19589),
#  ('tank cap', 26356),
#  ('cap fits', 4027),
#  ('beko tumble', 1865),
#  ('tumble dryer', 27620),
#  ('dryer door', 7916),
#  ('door lock', 7585),
#  ('lock catch', 15337),
#  ('hot pink', 12651),
#  ('patent leather', 19253),
#  ('leather brogue', 14728),
#  ('brogue shoes', 3342),
#  ('shoes size', 23718),
#  ('pack skoda', 18831),
#  ('skoda superb', 24293),
#  ('plug organic', 20144),
#  ('body jewellery', 2764),
#  ('girls boys', 10872),
#  ('nike air', 18028),
#  ('air max', 357),
#  ('white black', 29090),
#  ('black ladies', 2284),
#  ('ladies trainers', 14410),
#  ('vintage shabby', 28402),
#  ('shabby chic', 23418),
#  ('silver rhodium', 24043),
#  ('rhodium pl', 21968),
#  ('pair front', 18958),
#  ('roll bar', 22219),
#  ('bar link', 1514),
#  ('link drop', 15235),
#  ('wall mount', 28675),
#  ('mount bracket', 17217),
#  ('lcd tv', 14663),
#  ('pack boys', 18787),
#  ('grey marl', 11433),
#  ('new quality', 17873),
#  ('suit wedding', 25837),
#  ('age yrs', 306),
#  ('sterling silver', 25419),
#  ('new ladies', 17811),
#  ('skinny fit', 24268),
#  ('stretch jeans', 25638),
#  ('numatic henry', 18209),
#  ('henry hoover', 12189),
#  ('hoover vacuum', 12591),
#  ('cleaner dust', 5177),
#  ('dust bag', 8016),
#  ('bag pack', 1343),
#  ('engraved heart', 8516),
#  ('heart locket', 12058),
#  ('premier range', 20543),
#  ('range black', 21327),
#  ('toughened glass', 27165),
#  ('glass splashback', 10984),
#  ('real front', 21448),
#  ('front motorbike', 10212),
#  ('motorbike sintered', 17136),
#  ('sintered brake', 24108),
#  ('pads honda', 18900),
#  ('dishwasher dispenser', 7395),
#  ('dispenser lid', 7427),
#  ('catch kit', 4445),
#  ('new acer', 17684),
#  ('acer travelmate', 121),
#  ('vintage sewing', 28401),
#  ('sewing pattern', 23385),
#  ('pattern dress', 19273),
#  ('ring binder', 22055),
#  ('asv short', 1001),
#  ('short black', 23743),
#  ('black clutch', 2221),
#  ('clutch lever', 5337),
#  ('lever honda', 14997),
#  ('genuine land', 10703),
#  ('branded halogen', 3193),
#  ('halogen spotlight', 11723),
#  ('lamp light', 14464),
#  ('light bulb', 15086),
#  ('kitchen cabinet', 14059),
#  ('satin chrome', 22722),
#  ('deep impact', 6912),
#  ('impact socket', 12951),
#  ('socket drive', 24653),
#  ('black inch', 2273),
#  ('band ladies', 1465),
#  ('ladies ring', 14383),
#  ('ring size', 22086),
#  ('new replacement', 17880),
#  ('replacement lcd', 21804),
#  ('lcd screen', 14661),
#  ('led hd', 14838),
#  ('bosch super', 2975),
#  ('super spark', 25923),
#  ('seat altea', 23057),
#  ('brake pedal', 3177),
#  ('pedal light', 19389),
#  ('light switch', 15125),
#  ('ring gold', 22071),
#  ('gold chain', 11099),
#  ('chain jt', 4608),
#  ('jt sprocket', 13644),
#  ('sprocket kit', 25113),
#  ('kit inc', 13997),
#  ('carrier ducati', 4281),
#  ('ibm lenovo', 12846),
#  ('lenovo edge', 14943),
#  ('edge notebook', 8245),
#  ('notebook matte', 18158),
#  ('matte led', 16066),
#  ('led screen', 14866),
#  ('screen backlit', 22899),
#  ('backlit new', 1289),
#  ('opel manta', 18522),
#  ('rear screen', 21500),
#  ('screen plastic', 22928),
#  ('plastic chrome', 20000),
#  ('chrome moulding', 4954),
#  ('moulding trim', 17211),
#  ('sml med', 24560),
#  ('solid state', 24751),
#  ('state drive', 25303),
#  ('drive gb', 7831),
#  ('upgrade kit', 27960),
#  ('golf trolley', 11220),
#  ('trolley mount', 27521),
#  ('mount waterproof', 17241),
#  ('waterproof case', 28842),
#  ('case samsung', 4354),
#  ('samsung galaxy', 22626),
#  ('ladies womens', 14426),
#  ('kitten heel', 14072),
#  ('long leg', 15415),
#  ('skoda fabia', 24289),
#  ('petrol driveshaft', 19584),
#  ('driveshaft cv', 7870),
#  ('cv joints', 6588),
#  ('joints side', 13607),
#  ('side onwards', 23846),
#  ('money box', 16992),
#  ('mickey mouse', 16567),
#  ('usa flag', 28001),
#  ('vest tank', 28321),
#  ('tank top', 26364),
#  ('world cup', 29646),
#  ('cup football', 6456),
#  ('football soccer', 9955),
#  ('kit alfa', 13955),
#  ('alfa romeo', 430),
#  ('new compatible', 17735),
#  ('led notebook', 14860),
#  ('notebook laptop', 18155),
#  ('screen panel', 22927),
#  ('door wing', 7605),
#  ('wing mirror', 29332),
#  ('mirror glass', 16776),
#  ('glass ford', 10952),
#  ('ford transit', 10014),
#  ('right left', 22028),
#  ('lip gloss', 15255),
#  ('aztec snapback', 1202),
#  ('snapback caps', 24595),
#  ('flat peak', 9658),
#  ('peak baseball', 19353),
#  ('fresh prince', 10142),
#  ('strap back', 25579),
#  ('box gift', 3032),
#  ('gift set', 10821),
#  ('set pack', 23319),
#  ('fog light', 9895),
#  ('light bulbs', 15087),
#  ('bulbs hid', 3559),
#  ('xenon blue', 29762),
#  ('vauxhall corsa', 28206),
#  ('gold plated', 11154),
#  ('case back', 4316),
#  ('back plate', 1261),
#  ('boys brown', 3074),
#  ('casual formal', 4403),
#  ('high speed', 12301),
#  ('hard drive', 11861),
#  ('cable lead', 3785),
#  ('beowulf radiator', 1934),
#  ('radiator protector', 21257),
#  ('protector guard', 20799),
#  ('female plug', 9117),
#  ('plug female', 20129),
#  ('adapter convertor', 161),
#  ('large oil', 14561),
#  ('oil painting', 18409),
#  ('painting canvas', 18944),
#  ('canvas black', 4005),
#  ('collection books', 5501),
#  ('books set', 2887),
#  ('bull terrier', 3593),
#  ('leather dog', 14742),
#  ('dog collar', 7509),
#  ('inj gearbox', 13067),
#  ('gearbox diff', 10588),
#  ('diff driveshaft', 7274),
#  ('genuine oil', 10718),
#  ('vw volkswagen', 28601),
#  ('volkswagen polo', 28514),
#  ('windscreen sun', 29315),
#  ('sun shade', 25882),
#  ('eheim pick', 8305),
#  ('value pack', 28116),
#  ('men leather', 16226),
#  ('shoes brown', 23700),
#  ('brown style', 3409),
#  ('hyperpro progressive', 12823),
#  ('progressive front', 20743),
#  ('front fork', 10201),
#  ('fork spring', 10028),
#  ('spring kit', 25101),
#  ('kit aprilia', 13958),
#  ('aprilia rsv', 765),
#  ('rsv tuono', 22415),
#  ('new yellow', 17967),
#  ('yellow gold', 29920),
#  ('gold men', 11138),
#  ('men diamond', 16221),
#  ('diamond wedding', 7226),
#  ('wedding band', 28928),
#  ('car polish', 4126),
#  ('fibre channel', 9187),
#  ('channel fc', 4663),
#  ('pci card', 19334),
#  ('birthday anniversary', 2119),
#  ('anniversary farthing', 664),
#  ('farthing coin', 8988),
#  ('coin bookmark', 5454),
#  ('bookmark shiny', 2883),
#  ('fork stickers', 10030),
#  ('stickers decals', 25458),
#  ('decals transfers', 6865),
#  ('nokia classic', 18099),
#  ('lcd front', 14654),
#  ('front glass', 10202),
#  ('glass screen', 10977),
#  ('screen lens', 22920),
#  ('low voltage', 15533),
#  ('haynes manual', 11942),
#  ('audi petrol', 1054),
#  ('petrol diesel', 19583),
#  ('brake shoes', 3184),
#  ('opteka hd', 18552),
#  ('macro lens', 15716),
#  ('slr camera', 24485),
#  ('vitamin tablets', 28462),
#  ('high strength', 12304),
#  ('john lewis', 13577),
#  ('water supply', 28824),
#  ('hose tube', 12642),
#  ('tube pipe', 27596),
#  ('italian design', 13324),
#  ('satin finish', 22726),
#  ('slim fit', 24421),
#  ('ngk copper', 17991),
#  ('copper core', 5865),
#  ('core spark', 5898),
#  ('spark plugs', 24860),
#  ('plugs champion', 20165),
#  ('waterproof motorbike', 28850),
#  ('motorbike jacket', 17127),
#  ('jacket womens', 13391),
#  ('two tone', 27737),
#  ('ink jet', 13075),
#  ('photo print', 19683),
#  ('birthday shirt', 2148),
#  ('shirt vintage', 23651),
#  ('present age', 20563),
#  ('ladies gift', 14330),
#  ('table runner', 26248),
#  ('stainless front', 25206),
#  ('disc bolts', 7357),
#  ('evo bridgestone', 8706),
#  ('bridgestone battlax', 3275),
#  ('front tyre', 10242),
#  ('new silver', 17901),
#  ('silver tone', 24058),
#  ('rhinestone diamante', 21960),
#  ('diamante crystal', 7152),
#  ('pin brooch', 19775),
#  ('brooch wedding', 3363),
#  ('jeep wrangler', 13479),
#  ('driveshaft bootkit', 7867),
#  ('bootkit boot', 2918),
#  ('boot kit', 2902),
#  ('kit gaiter', 13991),
#  ('vw golf', 28583),
#  ('exhaust replacement', 8753),
#  ('flex flexi', 9704),
#  ('plastic push', 20011),
#  ('push fitting', 20984),
#  ('easter bunny', 8173),
#  ('lollipop sticks', 15387),
#  ('personalised name', 19559),
#  ('batman logo', 1621),
#  ('art wall', 903),
#  ('wall stickers', 28687),
#  ('stickers wall', 25467),
#  ('silver ct', 23983),
#  ('oval stud', 18717),
#  ('stud earrings', 25716),
#  ('ali baba', 435),
#  ('pc quad', 19319),
#  ('santa cruz', 22674),
#  ('bosch rear', 2969),
#  ('rear windscreen', 21517),
#  ('windscreen wiper', 29318),
#  ('wiper blade', 29379),
#  ('blade vw', 2464),
#  ('golf tdi', 11219),
#  ('air filter', 340),
#  ('filter vauxhall', 9332),
#  ('vauxhall vectra', 28217),
#  ('alloy clutch', 463),
#  ('renault espace', 21753),
#  ('driveshaft hub', 7871),
#  ('nut cv', 18229),
#  ('cv joint', 6587),
#  ('joint boot', 13589),
#  ('kit bootkit', 13964),
#  ('bootkit cone', 2919),
#  ('rover discovery', 22367),
#  ('discovery rear', 7377),
#  ('new dvd', 17747),
#  ('sale ladies', 22593),
#  ('black synthetic', 2397),
#  ('led white', 14882),
#  ('genuine bmw', 10663),
#  ('bmw mini', 2683),
#  ('mini one', 16707),
#  ('one cooper', 18469),
#  ('rear fog', 21482),
#  ('light red', 15111),
#  ('led board', 14817),
#  ('long sleeve', 15425),
#  ('mini stereo', 16720),
#  ('stereo jack', 25414),
#  ('twin phono', 27713),
#  ('phono cable', 19671),
#  ('personalised birthday', 19549),
#  ('birthday party', 2143),
#  ('party favour', 19161),
#  ('favour celebration', 9058),
#  ('gift tags', 10827),
#  ('celebrity mask', 4542),
#  ('mask cardboard', 15972),
#  ('cardboard face', 4222),
#  ('face fancy', 8892),
#  ('dress mask', 7744),
#  ('vintage womens', 28408),
#  ('light grey', 15098),
#  ('grey wool', 11453),
#  ('blazer jacket', 2484),
#  ('led laptop', 14847),
#  ('dazzling classic', 6805),
#  ('classic gold', 5140),
#  ('gold round', 11163),
#  ('round real', 22342),
#  ('real diamond', 21447),
#  ('diamond square', 7213),
#  ('square solitaire', 25140),
#  ('solitaire ring', 24759),
#  ('ring vs', 22097),
#  ('womens shoes', 29543),
#  ('size eur', 24144),
#  ('size black', 24134),
#  ('genuine bosch', 10665),
#  ('bosch washing', 2978),
#  ('machine carbon', 15691),
#  ('bc lamps', 1686),
#  ('yamaha motorcycle', 29878),
#  ('motorcycle oil', 17182),
#  ('filter filtrex', 9297),
#  ('antique silver', 710),
#  ('silver effect', 23995),
#  ('effect pendant', 8285),
#  ('silver chain', 23967),
#  ('gold silver', 11168),
#  ('silver diamond', 23990),
#  ('diamond accent', 7162),
#  ('blue topaz', 2638),
#  ('heart necklace', 12060),
#  ('art decor', 890),
#  ('stylish home', 25771),
#  ('evotech alloy', 8712),
#  ('alloy fuel', 466),
#  ('fuel cap', 10286),
#  ('cap race', 4037),
#  ('race gold', 21206),
#  ('gold red', 11161),
#  ('red fits', 21577),
#  ('fits suzuki', 9521),
#  ('suzuki bandit', 26037),
#  ('genuine dyson', 10679),
#  ('wet look', 29033),
#  ('full length', 10320),
#  ('muay thai', 17315),
#  ('case iphone', 4337),
#  ('motorcycle jacket', 17174),
#  ('clear double', 5209),
#  ('double bubble', 7629),
#  ('bubble screen', 3471),
#  ('screen kawasaki', 22915),
#  ('kawasaki zx6r', 13771),
#  ('coffee mug', 5434),
#  ('mug limited', 17335),
#  ('limited edition', 15183),
#  ('xmas gift', 29815),
#  ('silver wedding', 24063),
#  ('wedding ring', 28954),
#  ('ring set', 22083),
#  ('charm pendant', 4745),
#  ('pendant jewelry', 19461),
#  ('shaving razor', 23491),
#  ('cut throat', 6552),
#  ('womens oversized', 29527),
#  ('toy story', 27213),
#  ('buzz lightyear', 3715),
#  ('blue single', 2624),
#  ('single duvet', 24092),
#  ('duvet quilt', 8048),
#  ('quilt cover', 21170),
#  ('cover bedding', 6065),
#  ('bedding set', 1815),
#  ('full zip', 10328),
#  ('zip hoodie', 30049),
#  ('hoodie fleece', 12550),
#  ('fleece sweatshirt', 9693),
#  ('sweatshirt jumper', 26097),
#  ('top size', 27057),
#  ('size xl', 24179),
#  ('pistol boutique', 19924),
#  ('boutique mens', 3009),
#  ('mens fashion', 16295),
#  ('fashion top', 9006),
#  ('top hat', 27031),
#  ('hat sunglasses', 11916),
#  ('scoop neck', 22861),
#  ('forceps surgical', 9982),
#  ('surgical instruments', 25998),
#  ('red hearts', 21586),
#  ('hearts wedding', 12071),
#  ('wedding shoe', 28956),
#  ('electronic ignition', 8368),
#  ('ignition kit', 12905),
#  ('kit powerspark', 14026),
#  ('print bodycon', 20628),
#  ('bodycon dress', 2784),
#  ('mens gold', 16306),
#  ('hiphop bling', 12356),
#  ('new genuine', 17778),
#  ('genuine hipro', 10690),
#  ('hp notebook', 12708),
#  ('laptop adapter', 14518),
#  ('adapter charger', 159),
#  ('charger psu', 4715),
#  ('filter ford', 9301),
#  ('ford mondeo', 10000),
#  ('plugs vw', 20181),
#  ('motorcycle ngk', 17181),
#  ('copper spark', 5867),
#  ('right driver', 22021),
#  ('driver blue', 7852),
#  ('blue flat', 2569),
#  ('flat heated', 9652),
#  ('heated mirror', 12088),
#  ('glass alfa', 10931),
#  ('romeo spider', 22261),
#  ('patchwork cutters', 19247),
#  ('sugarcraft cake', 25828),
#  ('cake decoration', 3851),
#  ('decoration mould', 6897),
#  ('mould cutting', 17208),
#  ('cutting tool', 6581),
#  ('desert boots', 7027),
#  ('hi tops', 12240),
#  ('tops trainers', 27102),
#  ('fashion shoes', 9002),
#  ('disney mickey', 7414),
#  ('edition new', 8262),
#  ('hair dye', 11647),
#  ('dye la', 8085),
#  ('la riche', 14220),
#  ('riche directions', 22003),
#  ('directions semi', 7350),
#  ('semi permanent', 23146),
#  ('tint brush', 26860),
#  ('halogen bulb', 11715),
#  ('tail number', 26298),
#  ('number plate', 18214),
#  ('plate light', 20030),
#  ('seat ibiza', 23065),
#  ('set euro', 23292),
#  ('euro coins', 8663),
#  ('coins unc', 5469),
#  ('new womens', 17959),
#  ('ladies girls', 14331),
#  ('pink dress', 19828),
#  ('dress top', 7773),
#  ('trim clips', 27482),
#  ('spot heeled', 25070),
#  ('genuine acer', 10647),
#  ('acer aspire', 117),
#  ('aspire laptop', 951),
#  ('laptop power', 14537),
#  ('power supply', 20484),
#  ('supply cord', 25973),
#  ('green silver', 11391),
#  ('men blue', 16214),
#  ('blue dial', 2562),
#  ('dial black', 7139),
#  ('black leather', 2289),
#  ('strap watch', 25593),
#  ('ladies spot', 14399),
#  ('spot ankle', 25066),
#  ('ankle boot', 639),
#  ('purple blue', 20952),
#  ('man made', 15845),
#  ('ladies strapless', 14401),
#  ('red white', 21627),
#  ('white polka', 29171),
#  ('polka dot', 20276),
#  ('wetsuit surf', 29036),
#  ('top end', 27027),
#  ('flow sensor', 9806),
#  ('labels sheet', 14229),
#  ('sheet sheets', 23519),
#  ('toyota avensis', 27218),
#  ('front fog', 10199),
#  ('light lamp', 15102),
#  ('lamp uk', 14472),
#  ('passenger side', 19216),
#  ('bosch dishwasher', 2964),
#  ('flow meter', 9805),
#  ('junior kids', 13697),
#  ('green navy', 11376),
#  ('navy red', 17547),
#  ('bobble hat', 2750),
#  ('new official', 17845),
#  ('various artists', 28178),
#  ('clear plastic', 5220),
#  ('high performance', 12289),
#  ('performance silicone', 19529),
#  ('silicone radiator', 23930),
#  ('radiator hoses', 21255),
#  ('mazda front', 16108),
#  ('front right', 10226),
#  ('right abs', 22017),
#  ('helmet visor', 12169),
#  ('driver right', 7859),
#  ('wide angle', 29237),
#  ('angle heated', 615),
#  ('heated wing', 12092),
#  ('wing door', 29331),
#  ('door mirror', 7587),
#  ('mg zs', 16535),
#  ('honda civic', 12504),
#  ('brake pad', 3175),
#  ('fitting kit', 9546),
#  ('cotton terry', 6013),
#  ('socks black', 24671),
#  ('black grey', 2263),
#  ('grey white', 11452),
#  ('presentation box', 20566),
#  ('water pump', 28821),
#  ('control switch', 5775),
#  ('merry christmas', 16454),
#  ('silver red', 24042),
#  ('red gold', 21581),
#  ('gold foil', 11127),
#  ...]

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
cv_min_5_max_07_ngr_ctxt = CountVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2), preprocessor=clean_text, stop_words=stop_words)
cv_min_5_max_07_ngr_ctxt.fit(X_tr, y_tr)
#How many tokens 
print("How many unique tokens in cv_min_5_max_07_ngr ???")
print(len( cv_min_5_max_07_ngr_ctxt.vocabulary_))
[x for x in cv_min_5_max_07_ngr_ctxt.vocabulary_.items() if len(x[0].split()) > 1]

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
# from sklearn.feature_extraction.text import CountVectorizer
# import re
#
# def clean_text(t):
#     t = t.lower()
#     t = re.sub("[^A-Za-z0-9]"," ",t)
#     t = re.sub("[0-9]+","#",t)
#     return t
#
# vectorizers = [
#      ("vanilla",
#           CountVectorizer())
#     ,("preprocessing",
#           CountVectorizer(preprocessor=clean_text))
#     ,("preprocessing + min_df=10",
#           CountVectorizer(preprocessor=clean_text,
#                           min_df=10))
# ]
#
# for vect_name, vect in vectorizers:
#     print(vect_name)
#     vect.fit(X_tr)
#
#     print(list(vect.get_feature_names())[:10])
#     print(len(vect.get_feature_names()))
# </div>

# %% [markdown]
# Stemming
# ------------------
#
# Linguistic normalization in which variant forms are reduced to a common form
#
#     connection
#     connections
#     connective     --->   connect
#     connected
#     connecting
#
# Usage:
#
#     import snowballstemmer
#
#     stemmer = snowballstemmer.stemmer('english')
#     print(stemmer.stemWords("We are the world".split()))

# %%
import snowballstemmer

stemmer = snowballstemmer.stemmer('english')
print(stemmer.stemWords("We are the world".split()))
# Out:
# ['We', 'are', 'the', 'world']

# %% [markdown]
# Putting it into a pipeline
# ----------------------
#
# Now that we know how to transform text data, let's put it into a pipeline.
#
# 1. Create a pipeline with `CountVectorizer`, `StandardScaler` and `SGDClassifier` as your final algorithm
#     a) use alternative format for pipeline definition when you name the steps - refer to the documentation how to do this
# 2. Using ```sklearn.metrics.classification_report``` create a report about your classifier

# %%
##########################
# put your solution here #
##########################

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.cross_validation import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.grid_search import GridSearchCV

import snowballstemmer

stemmer = snowballstemmer.stemmer('english')

from nltk.tokenize import word_tokenize

def clean_text2(str):
    str = str.lower()
    str = re.sub(r'\b[0-9]+[A-Za-z]+\b', '', str)
    str = re.sub(r'\b[0-9]+\b', '', str)
    str = re.sub(r'\b[A-Za-z]+[0-9]+\b', '', str)
    return str

def stemmed_words(doc):
    return [stemmer.stemWords(w) for w in doc]

def tok_with_stemmer(doc):
    tokenized =  word_tokenize(doc)
    #return tokenized
    return stemmer.stemWords(tokenized)
    

#clf = make_pipeline(CountVectorizer(), SGDClassifier())

# %%
clf = Pipeline([
    ('vectorizer', CountVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2), preprocessor=clean_text2, stop_words=stop_words, 
                                   tokenizer=tok_with_stemmer)),
    ('scaler', StandardScaler(copy=True, with_mean=False, with_std=False)),
    ('sgd', SGDClassifier())
])

preds = cross_val_predict(clf, 
                          X_tr, 
                          y_tr, 
                          cv=8, n_jobs=-1, verbose=True)

print(classification_report(y_tr, preds))

clf.fit(X_tr, y_tr)

# %%
clf2 = Pipeline([
    ('vectorizer', CountVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2), preprocessor=clean_text2, stop_words=stop_words, 
                                   tokenizer=tok_with_stemmer)),
    ('scaler', StandardScaler(copy=True, with_mean=False, with_std=False)),
    ('sgd', SGDClassifier())
])

preds = cross_val_predict(clf2, 
                          X_tr, 
                          y_tr, 
                          cv=8, n_jobs=-1, verbose=True)

print(classification_report(y_tr, preds))

clf2.fit(X_tr, y_tr)
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:  2.3min remaining:  6.9min
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:  2.3min finished
#                                 precision    recall  f1-score   support
#
#                       Antiques       0.74      0.36      0.48       337
#                            Art       0.72      0.73      0.72       981
#                           Baby       0.88      0.70      0.78      1287
#      Books, Comics & Magazines       0.88      0.78      0.83       793
#  Business, Office & Industrial       0.80      0.64      0.71      5133
#          Cameras & Photography       0.92      0.88      0.90      1626
#      Cell Phones & Accessories       0.94      0.22      0.36       131
#   Clothes, Shoes & Accessories       0.93      0.97      0.95     30295
#            Coins & Paper Money       0.93      0.90      0.91       373
#                   Collectibles       0.84      0.73      0.78      4460
# Computers/Tablets & Networking       0.93      0.95      0.94     12479
#           Consumer Electronics       0.79      0.45      0.58       220
#                         Crafts       0.89      0.87      0.88      6030
#               DVDs, Films & TV       0.90      0.91      0.90      1045
#                  Dolls & Bears       0.92      0.87      0.89       457
#      Entertainment Memorabilia       0.00      0.00      0.00        10
#                 Events Tickets       0.00      0.00      0.00         1
#                Everything Else       0.88      0.61      0.72       296
#                 Garden & Patio       0.85      0.74      0.79      1950
#                Health & Beauty       0.85      0.90      0.87      6137
#              Holidays & Travel       0.00      0.00      0.00         3
#          Home, Furniture & DIY       0.88      0.90      0.89     23186
#            Jewellery & Watches       0.96      0.97      0.96     11202
#  Mobile Phones & Communication       0.92      0.93      0.93      6935
#                          Music       0.97      0.93      0.95      2432
#     Musical Instruments & Gear       0.87      0.67      0.76       692
#                   Pet Supplies       0.92      0.83      0.87      1124
#     Pottery, Porcelain & Glass       0.79      0.55      0.65       164
#                 Sound & Vision       0.83      0.77      0.80      3378
#                 Sporting Goods       0.86      0.81      0.83      8531
#             Sports Memorabilia       0.85      0.60      0.70       536
#                         Stamps       0.92      0.88      0.90       161
#                   Toys & Games       0.90      0.82      0.86      5290
#                         Travel       0.00      0.00      0.00         2
#    Vehicle Parts & Accessories       0.94      0.98      0.96     41354
#         Video Games & Consoles       0.93      0.84      0.88       793
#           Wholesale & Job Lots       0.77      0.50      0.61       176
#
#                    avg / total       0.91      0.91      0.91    180000
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.7, max_features=None, min_df=5,
#         ngram_range=(1, 2),
#         preprocessor=<function clean_text2 ...='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False))])

# %%
clf3 = Pipeline([
    ('vectorizer', TfidfVectorizer(min_df=5, max_df=0.7, ngram_range=(1,2), preprocessor=clean_text2, stop_words=stop_words, 
                                   tokenizer=tok_with_stemmer)),
    ('scaler', StandardScaler(copy=True, with_mean=False, with_std=False)),
    ('sgd', SGDClassifier(alpha=0.001))
])

preds = cross_val_predict(clf, 
                          X_tr, 
                          y_tr, 
                          cv=8, n_jobs=-1, verbose=True)

print(classification_report(y_tr, preds))

clf3.fit(X_tr, y_tr)
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed: 11.8min remaining: 35.5min
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed: 12.0min finished
#                                 precision    recall  f1-score   support
#
#                       Antiques       0.67      0.08      0.15       195
#                            Art       0.66      0.68      0.67       542
#                           Baby       0.82      0.61      0.70       649
#      Books, Comics & Magazines       0.81      0.65      0.72       402
#  Business, Office & Industrial       0.79      0.46      0.58      2586
#          Cameras & Photography       0.87      0.77      0.81       778
#      Cell Phones & Accessories       0.00      0.00      0.00        53
#   Clothes, Shoes & Accessories       0.87      0.97      0.92     15037
#            Coins & Paper Money       0.86      0.78      0.82       171
#                   Collectibles       0.82      0.58      0.68      2229
# Computers/Tablets & Networking       0.89      0.93      0.91      6080
#           Consumer Electronics       0.88      0.16      0.27       130
#                         Crafts       0.84      0.77      0.80      2997
#               DVDs, Films & TV       0.87      0.90      0.89       548
#                  Dolls & Bears       0.83      0.79      0.81       233
#      Entertainment Memorabilia       0.00      0.00      0.00         8
#                Everything Else       0.91      0.40      0.56       130
#                 Garden & Patio       0.81      0.57      0.67       937
#                Health & Beauty       0.80      0.81      0.81      2986
#              Holidays & Travel       0.00      0.00      0.00         3
#          Home, Furniture & DIY       0.82      0.86      0.84     11550
#            Jewellery & Watches       0.91      0.96      0.94      5710
#  Mobile Phones & Communication       0.88      0.92      0.90      3584
#                          Music       0.93      0.93      0.93      1215
#     Musical Instruments & Gear       0.89      0.57      0.69       414
#                   Pet Supplies       0.91      0.68      0.78       546
#     Pottery, Porcelain & Glass       0.76      0.28      0.41        79
#                 Sound & Vision       0.80      0.65      0.72      1672
#                 Sporting Goods       0.84      0.67      0.75      4276
#             Sports Memorabilia       0.85      0.44      0.58       269
#                         Stamps       0.90      0.88      0.89        73
#                   Toys & Games       0.84      0.70      0.76      2576
#                         Travel       0.00      0.00      0.00         1
#    Vehicle Parts & Accessories       0.89      0.97      0.93     20818
#         Video Games & Consoles       0.88      0.77      0.82       426
#           Wholesale & Job Lots       0.91      0.41      0.57        97
#
#                    avg / total       0.86      0.86      0.85     90000
# Pipeline(memory=None,
#      steps=[('vectorizer', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.7, max_features=None, min_df=5,
#         ngram_range=(1, 3), norm='l2',
#         preprocessor=<function c...='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False))])

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# from sklearn.pipeline import Pipeline
# from sklearn.linear_model import SGDClassifier
# from sklearn.cross_validation import cross_val_predict
# from sklearn.metrics import classification_report
# from sklearn.preprocessing import StandardScaler
# from sklearn.grid_search import GridSearchCV
#
# clf = Pipeline([('vect', CountVectorizer(min_df=10, preprocessor=clean_text)),
#                 ('scaling', StandardScaler(with_mean=False)),
#                 ('clf', SGDClassifier())])
#
# preds = cross_val_predict(clf,
#                           X_tr,
#                           y_tr,
#                           cv=8, n_jobs=-1, verbose=True)
#
# print(classification_report(y_tr, preds)
#
#
# </div>

# %% [markdown]
# Grid search
# --------------------------
#
# Scikit-learn has `GridSearchCV` and `RandomizedSearchCV`. Both have the same functionality and can be used to find good parameters for the models. What is great about both these classes that they are both transformers - they return an estimator so you can chain them and put in your pipeline.
#
# **GridSearchCV** - you specify the exact values of the parameters you want to test
# **RandomizedSearchCV** - you specify ranges of parameters
#
# Exercise
# ----------------------
#
# 1. Use `GridSearchCV` or `RandomizedSearchCV` to find the best parameters for the models. Check at least 2 parameters.
#
# 2. Inspect the attribute `cv_results_` after fitting. It gives a nice representation of the learning.

# %%
##########################
# put your solution here #
##########################
pipeline = Pipeline([
    ('vect', CountVectorizer(preprocessor=clean_text2, stop_words=stop_words, 
                                   tokenizer=tok_with_stemmer, min_df=5, ngram_range=(1,2), )),
    ('scaler', StandardScaler(copy=True, with_mean=False, with_std=False)),
    ('sgd', SGDClassifier(alpha= 0.0001))
])

clf = GridSearchCV(pipeline, { 
                       # 'sgd__alpha':[0.0001, 0.00001]
                        #'vect__min_df':[1,5,10,25],
                         'vect__max_df':[0.65, 0.7, 0.75]
                        #'vect__ngram_range':[(1,1),(1,2),(1,3)]
})

clf.fit(X_tr, y_tr)

print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'vect__max_df': 0.7}
# 0.8834888888888889

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
#
# print("Grid search")
# print()
#
# params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
#           'vect__analyzer': ["word","char"],
#           'vect__binary': [True, False]}
#
# grid_clf = GridSearchCV(clf, params, n_jobs=1, verbose=True)
# grid_clf.fit(X_tr, y_tr)
#
# best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])
#
#
# for params, score, _ in best_params:
#     print(score, params)
#
# print("Randomized search")
# print()
#
# params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
#           'vect__analyzer': ["word","char"],
#           'model__lr__dimensions': [100, 200]}
#
# grid_clf = RandomizedSearchCV(clf, params, n_jobs=1, verbose=True, n_iter=8)
# grid_clf.fit(np.array(X_tr[:10000]), y_tr[:10000])
#
# best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])
#
# for params, score, _ in best_params:
#     print(score, params)
#
# </div>

# %% [markdown]
# Useful materials
#
# 1. http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# 2. http://scikit-learn.org/stable/auto_examples/model_selection/randomized_search.html
